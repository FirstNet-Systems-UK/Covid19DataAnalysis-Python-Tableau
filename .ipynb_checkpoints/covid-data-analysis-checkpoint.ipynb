# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
from plotly.subplots import make_subplots
from datetime import datetime

# %%
covid_df=pd.read_csv("covid_19_india.csv")

# %%
covid_df.head(1)
# Out:
#    Sno        Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 0  1.0  2020-01-30  6:00 PM               Kerala                       1
#
#   ConfirmedForeignNational  Cured  Deaths  Confirmed
# 0                        0    0.0     0.0        1.0

# %%
covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15114 entries, 0 to 15113
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Sno                       15086 non-null  float64
#  1   Date                      15086 non-null  object
#  2   Time                      15086 non-null  object
#  3   State/UnionTerritory      15086 non-null  object
#  4   ConfirmedIndianNational   15086 non-null  object
#  5   ConfirmedForeignNational  15086 non-null  object
#  6   Cured                     15086 non-null  float64
#  7   Deaths                    15086 non-null  float64
#  8   Confirmed                 15086 non-null  float64
# dtypes: float64(4), object(5)
# memory usage: 1.0+ MB

# %%
covid_df.describe()
# Out:
#                 Sno         Cured        Deaths     Confirmed
# count  15086.000000  1.508600e+04  15086.000000  1.508600e+04
# mean    7543.500000  1.747937e+05   2721.084449  1.942820e+05
# std     4355.097416  3.648330e+05   7182.672358  4.095184e+05
# min        1.000000  0.000000e+00      0.000000  0.000000e+00
# 25%     3772.250000  1.685000e+03     12.000000  2.935500e+03
# 50%     7543.500000  1.964700e+04    364.000000  2.608150e+04
# 75%    11314.750000  2.087552e+05   2170.000000  2.216012e+05
# max    15086.000000  4.927480e+06  83777.000000  5.433506e+06

# %%
vaccine_df=pd.read_csv("covid_vaccine_statewise.csv")

# %%
vaccine_df
# Out:
#       Updated On        State  Total Doses Administered  Sessions   Sites   \
# 0     16/01/2021        India                   48276.0    3455.0   2957.0
# 1     17/01/2021        India                   58604.0    8532.0   4954.0
# 2     18/01/2021        India                   99449.0   13611.0   6583.0
# 3     19/01/2021        India                  195525.0   17855.0   7951.0
# 4     20/01/2021        India                  251280.0   25472.0  10504.0
# ...          ...          ...                       ...       ...      ...
# 7840  11/08/2021  West Bengal                       NaN       NaN      NaN
# 7841  12/08/2021  West Bengal                       NaN       NaN      NaN
# 7842  13/08/2021  West Bengal                       NaN       NaN      NaN
# 7843  14/08/2021  West Bengal                       NaN       NaN      NaN
# 7844  15/08/2021  West Bengal                       NaN       NaN      NaN
#
#       First Dose Administered  Second Dose Administered  \
# 0                     48276.0                       0.0
# 1                     58604.0                       0.0
# 2                     99449.0                       0.0
# 3                    195525.0                       0.0
# 4                    251280.0                       0.0
# ...                       ...                       ...
# 7840                      NaN                       NaN
# 7841                      NaN                       NaN
# 7842                      NaN                       NaN
# 7843                      NaN                       NaN
# 7844                      NaN                       NaN
#
#       Male (Doses Administered)  Female (Doses Administered)  \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# 4                           NaN                          NaN
# ...                         ...                          ...
# 7840                        NaN                          NaN
# 7841                        NaN                          NaN
# 7842                        NaN                          NaN
# 7843                        NaN                          NaN
# 7844                        NaN                          NaN
#
#       Transgender (Doses Administered)  ...  18-44 Years (Doses Administered)  \
# 0                                  NaN  ...                               NaN
# 1                                  NaN  ...                               NaN
# 2                                  NaN  ...                               NaN
# 3                                  NaN  ...                               NaN
# 4                                  NaN  ...                               NaN
# ...                                ...  ...                               ...
# 7840                               NaN  ...                               NaN
# 7841                               NaN  ...                               NaN
# 7842                               NaN  ...                               NaN
# 7843                               NaN  ...                               NaN
# 7844                               NaN  ...                               NaN
#
#       45-60 Years (Doses Administered)  60+ Years (Doses Administered)  \
# 0                                  NaN                             NaN
# 1                                  NaN                             NaN
# 2                                  NaN                             NaN
# 3                                  NaN                             NaN
# 4                                  NaN                             NaN
# ...                                ...                             ...
# 7840                               NaN                             NaN
# 7841                               NaN                             NaN
# 7842                               NaN                             NaN
# 7843                               NaN                             NaN
# 7844                               NaN                             NaN
#
#       18-44 Years(Individuals Vaccinated)  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ...                                   ...
# 7840                                  NaN
# 7841                                  NaN
# 7842                                  NaN
# 7843                                  NaN
# 7844                                  NaN
#
#       45-60 Years(Individuals Vaccinated)  60+ Years(Individuals Vaccinated)  \
# 0                                     NaN                                NaN
# 1                                     NaN                                NaN
# 2                                     NaN                                NaN
# 3                                     NaN                                NaN
# 4                                     NaN                                NaN
# ...                                   ...                                ...
# 7840                                  NaN                                NaN
# 7841                                  NaN                                NaN
# 7842                                  NaN                                NaN
# 7843                                  NaN                                NaN
# 7844                                  NaN                                NaN
#
#       Male(Individuals Vaccinated)  Female(Individuals Vaccinated)  \
# 0                          23757.0                         24517.0
# 1                          27348.0                         31252.0
# 2                          41361.0                         58083.0
# 3                          81901.0                        113613.0
# 4                          98111.0                        153145.0
# ...                            ...                             ...
# 7840                           NaN                             NaN
# 7841                           NaN                             NaN
# 7842                           NaN                             NaN
# 7843                           NaN                             NaN
# 7844                           NaN                             NaN
#
#       Transgender(Individuals Vaccinated)  Total Individuals Vaccinated
# 0                                     2.0                       48276.0
# 1                                     4.0                       58604.0
# 2                                     5.0                       99449.0
# 3                                    11.0                      195525.0
# 4                                    24.0                      251280.0
# ...                                   ...                           ...
# 7840                                  NaN                           NaN
# 7841                                  NaN                           NaN
# 7842                                  NaN                           NaN
# 7843                                  NaN                           NaN
# 7844                                  NaN                           NaN
#
# [7845 rows x 24 columns]

# %%
covid_df.drop(["Sno","Time","ConfirmedIndianNational","ConfirmedForeignNational"],inplace=True,axis=1)

# %%
covid_df.head(1)
# Out:
#          Date State/UnionTerritory  Cured  Deaths  Confirmed
# 0  2020-01-30               Kerala    0.0     0.0        1.0

# %%
covid_df["Date"]=pd.to_datetime(covid_df["Date"] ,format='%Y-%m-%d')

# %%
covid_df.head(1)
# Out:
#         Date State/UnionTerritory  Cured  Deaths  Confirmed
# 0 2020-01-30               Kerala    0.0     0.0        1.0

# %%
#finding active cases

# %%
covid_df["Active_Cases"]=covid_df['Confirmed'] - (covid_df['Cured'] +covid_df['Deaths'])

# %%
covid_df.tail(7)
# Out:
#       Date State/UnionTerritory  Cured  Deaths  Confirmed  Active_Cases
# 15107  NaT                  NaN    NaN     NaN        NaN           NaN
# 15108  NaT                  NaN    NaN     NaN        NaN           NaN
# 15109  NaT                  NaN    NaN     NaN        NaN           NaN
# 15110  NaT                  NaN    NaN     NaN        NaN           NaN
# 15111  NaT                  NaN    NaN     NaN        NaN           NaN
# 15112  NaT                  NaN    NaN     NaN        NaN           NaN
# 15113  NaT                  NaN    NaN     NaN        NaN           NaN

# %%
statewise=pd.pivot_table(covid_df,values=["Confirmed","Deaths","Cured"],index="State/UnionTerritory",aggfunc = max)

# %%
statewise
# Out:
#                                           Confirmed      Cured   Deaths
# State/UnionTerritory
# Andaman and Nicobar Islands                  6674.0     6359.0     92.0
# Andhra Pradesh                            1475372.0  1254291.0   9580.0
# Arunachal Pradesh                           22462.0    19977.0     88.0
# Assam                                      340858.0   290774.0   2344.0
# Bihar                                      664115.0   595377.0   4039.0
# Cases being reassigned to states             9265.0        0.0      0.0
# Chandigarh                                  56513.0    48831.0    647.0
# Chhattisgarh                               925531.0   823113.0  12036.0
# Dadra and Nagar Haveli and Daman and Diu     9652.0     8944.0      4.0
# Daman & Diu                                     2.0        0.0      0.0
# Delhi                                     1402873.0  1329899.0  22111.0
# Goa                                        138776.0   112633.0   2197.0
# Gujarat                                    766201.0   660489.0   9269.0
# Haryana                                    709689.0   626852.0   6923.0
# Himachal Pradesh                           166678.0   129330.0   2460.0
# Jammu and Kashmir                          251919.0   197701.0   3293.0
# Jharkhand                                  320934.0   284805.0   4601.0
# Karnataka                                 2272374.0  1674487.0  22838.0
# Kerala                                    2200706.0  1846105.0   6612.0
# Ladakh                                      16784.0    15031.0    170.0
# Lakshadweep                                  5212.0     3915.0     15.0
# Madhya Pradesh                             742718.0   652612.0   7139.0
# Maharashtra                               5433506.0  4927480.0  83777.0
# Manipur                                     40683.0    33466.0    612.0
# Meghalaya                                   24872.0    19185.0    355.0
# Mizoram                                      9252.0     7094.0     29.0
# Nagaland                                    18714.0    14079.0    228.0
# Odisha                                     633302.0   536595.0   2357.0
# Puducherry                                  87749.0    69060.0   1212.0
# Punjab                                     511652.0   427058.0  12317.0
# Rajasthan                                  879664.0   713129.0   7080.0
# Sikkim                                      11689.0     8427.0    212.0
# Tamil Nadu                                1664350.0  1403052.0  18369.0
# Telangana                                  536766.0   485644.0   3012.0
# Telengana                                  443360.0   362160.0   2312.0
# Tripura                                     42776.0    36402.0    450.0
# Unassigned                                     77.0        0.0      0.0
# Uttar Pradesh                             1637663.0  1483249.0  18072.0
# Uttarakhand                                295790.0   214426.0   5132.0
# West Bengal                               1171861.0  1026492.0  13576.0

# %%
statewise["Recovery Rate"]=statewise["Cured"]*100/statewise["Confirmed"]

# %%
statewise.head(3)
# Out:
#                              Confirmed      Cured  Deaths  Recovery Rate
# State/UnionTerritory
# Andaman and Nicobar Islands     6674.0     6359.0    92.0      95.280192
# Andhra Pradesh               1475372.0  1254291.0  9580.0      85.015237
# Arunachal Pradesh              22462.0    19977.0    88.0      88.936871

# %%
statewise["Mortality Rate"]=statewise["Deaths"]*100/statewise["Confirmed"]

# %%
statewise.head(1)
# Out:
#                              Confirmed   Cured  Deaths  Recovery Rate  \
# State/UnionTerritory
# Andaman and Nicobar Islands     6674.0  6359.0    92.0      95.280192
#
#                              Mortality Rate
# State/UnionTerritory
# Andaman and Nicobar Islands        1.378484

# %%
statewise=statewise.sort_values(by = "Confirmed" , ascending=False)

# %%
statewise.head(5)
# Out:
#                       Confirmed      Cured   Deaths  Recovery Rate  \
# State/UnionTerritory
# Maharashtra           5433506.0  4927480.0  83777.0      90.686934
# Karnataka             2272374.0  1674487.0  22838.0      73.688882
# Kerala                2200706.0  1846105.0   6612.0      83.886944
# Tamil Nadu            1664350.0  1403052.0  18369.0      84.300297
# Uttar Pradesh         1637663.0  1483249.0  18072.0      90.571076
#
#                       Mortality Rate
# State/UnionTerritory
# Maharashtra                 1.541859
# Karnataka                   1.005028
# Kerala                      0.300449
# Tamil Nadu                  1.103674
# Uttar Pradesh               1.103524

# %%
statewise.style.background_gradient(cmap ="cubehelix")
# Out:
# <style type="text/css">
# #T_d9632_row0_col0, #T_d9632_row0_col1, #T_d9632_row0_col2, #T_d9632_row16_col4, #T_d9632_row36_col3 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_d9632_row0_col3, #T_d9632_row4_col3, #T_d9632_row15_col3 {
#   background-color: #e9f8f2;
#   color: #000000;
# }
# #T_d9632_row0_col4 {
#   background-color: #d487b2;
#   color: #f1f1f1;
# }
# #T_d9632_row1_col0, #T_d9632_row31_col4 {
#   background-color: #637a2f;
#   color: #f1f1f1;
# }
# #T_d9632_row1_col1 {
#   background-color: #2d7038;
#   color: #f1f1f1;
# }
# #T_d9632_row1_col2, #T_d9632_row5_col0, #T_d9632_row5_col4, #T_d9632_row6_col1 {
#   background-color: #185b48;
#   color: #f1f1f1;
# }
# #T_d9632_row1_col3 {
#   background-color: #c4bdf1;
#   color: #000000;
# }
# #T_d9632_row1_col4 {
#   background-color: #607a2f;
#   color: #f1f1f1;
# }
# #T_d9632_row2_col0, #T_d9632_row12_col4 {
#   background-color: #577a2f;
#   color: #f1f1f1;
# }
# #T_d9632_row2_col1 {
#   background-color: #417731;
#   color: #f1f1f1;
# }
# #T_d9632_row2_col2, #T_d9632_row17_col0 {
#   background-color: #180f25;
#   color: #f1f1f1;
# }
# #T_d9632_row2_col3 {
#   background-color: #cce9ef;
#   color: #000000;
# }
# #T_d9632_row2_col4, #T_d9632_row13_col0 {
#   background-color: #1b1c3a;
#   color: #f1f1f1;
# }
# #T_d9632_row3_col0 {
#   background-color: #206840;
#   color: #f1f1f1;
# }
# #T_d9632_row3_col1 {
#   background-color: #1a6046;
#   color: #f1f1f1;
# }
# #T_d9632_row3_col2 {
#   background-color: #15464e;
#   color: #f1f1f1;
# }
# #T_d9632_row3_col3 {
#   background-color: #cdeaef;
#   color: #000000;
# }
# #T_d9632_row3_col4, #T_d9632_row4_col4 {
#   background-color: #817a37;
#   color: #f1f1f1;
# }
# #T_d9632_row4_col0, #T_d9632_row4_col1 {
#   background-color: #1f6741;
#   color: #f1f1f1;
# }
# #T_d9632_row4_col2, #T_d9632_row7_col0, #T_d9632_row17_col4 {
#   background-color: #15444f;
#   color: #f1f1f1;
# }
# #T_d9632_row5_col1 {
#   background-color: #16554b;
#   color: #f1f1f1;
# }
# #T_d9632_row5_col2, #T_d9632_row14_col0 {
#   background-color: #1b1a36;
#   color: #f1f1f1;
# }
# #T_d9632_row5_col3, #T_d9632_row26_col3 {
#   background-color: #d0ecef;
#   color: #000000;
# }
# #T_d9632_row6_col0 {
#   background-color: #16574b;
#   color: #f1f1f1;
# }
# #T_d9632_row6_col2 {
#   background-color: #17584a;
#   color: #f1f1f1;
# }
# #T_d9632_row6_col3 {
#   background-color: #fdfefe;
#   color: #000000;
# }
# #T_d9632_row6_col4 {
#   background-color: #d48cbe;
#   color: #f1f1f1;
# }
# #T_d9632_row7_col1 {
#   background-color: #16404e;
#   color: #f1f1f1;
# }
# #T_d9632_row7_col2, #T_d9632_row9_col0, #T_d9632_row29_col4 {
#   background-color: #192c47;
#   color: #f1f1f1;
# }
# #T_d9632_row7_col3 {
#   background-color: #dbf3ef;
#   color: #000000;
# }
# #T_d9632_row7_col4 {
#   background-color: #937a40;
#   color: #f1f1f1;
# }
# #T_d9632_row8_col0 {
#   background-color: #182f49;
#   color: #f1f1f1;
# }
# #T_d9632_row8_col1 {
#   background-color: #192d48;
#   color: #f1f1f1;
# }
# #T_d9632_row8_col2, #T_d9632_row10_col0 {
#   background-color: #1a2441;
#   color: #f1f1f1;
# }
# #T_d9632_row8_col3, #T_d9632_row19_col3, #T_d9632_row29_col3 {
#   background-color: #e0f5f0;
#   color: #000000;
# }
# #T_d9632_row8_col4 {
#   background-color: #b97964;
#   color: #f1f1f1;
# }
# #T_d9632_row9_col1, #T_d9632_row16_col2 {
#   background-color: #1a2543;
#   color: #f1f1f1;
# }
# #T_d9632_row9_col2, #T_d9632_row11_col2, #T_d9632_row12_col2 {
#   background-color: #181027;
#   color: #f1f1f1;
# }
# #T_d9632_row9_col3 {
#   background-color: #c5dff2;
#   color: #000000;
# }
# #T_d9632_row9_col4 {
#   background-color: #2b6f39;
#   color: #f1f1f1;
# }
# #T_d9632_row10_col1, #T_d9632_row11_col0 {
#   background-color: #1a213e;
#   color: #f1f1f1;
# }
# #T_d9632_row10_col2 {
#   background-color: #1a1835;
#   color: #f1f1f1;
# }
# #T_d9632_row10_col3 {
#   background-color: #d4efef;
#   color: #000000;
# }
# #T_d9632_row10_col4 {
#   background-color: #a1794a;
#   color: #f1f1f1;
# }
# #T_d9632_row11_col1, #T_d9632_row12_col0, #T_d9632_row35_col4 {
#   background-color: #1b1f3d;
#   color: #f1f1f1;
# }
# #T_d9632_row11_col3 {
#   background-color: #dcf3ef;
#   color: #000000;
# }
# #T_d9632_row11_col4 {
#   background-color: #54792f;
#   color: #f1f1f1;
# }
# #T_d9632_row12_col1 {
#   background-color: #1b1e3b;
#   color: #f1f1f1;
# }
# #T_d9632_row12_col3 {
#   background-color: #def4ef;
#   color: #000000;
# }
# #T_d9632_row13_col1, #T_d9632_row37_col4 {
#   background-color: #1b1b38;
#   color: #f1f1f1;
# }
# #T_d9632_row13_col2 {
#   background-color: #110815;
#   color: #f1f1f1;
# }
# #T_d9632_row13_col3, #T_d9632_row31_col3 {
#   background-color: #e3f6f0;
#   color: #000000;
# }
# #T_d9632_row13_col4 {
#   background-color: #16534c;
#   color: #f1f1f1;
# }
# #T_d9632_row14_col1 {
#   background-color: #1a1733;
#   color: #f1f1f1;
# }
# #T_d9632_row14_col2, #T_d9632_row17_col2, #T_d9632_row18_col2, #T_d9632_row22_col0, #T_d9632_row22_col2 {
#   background-color: #0b040c;
#   color: #f1f1f1;
# }
# #T_d9632_row14_col3 {
#   background-color: #cfebef;
#   color: #000000;
# }
# #T_d9632_row14_col4 {
#   background-color: #192845;
#   color: #f1f1f1;
# }
# #T_d9632_row15_col0, #T_d9632_row15_col1 {
#   background-color: #1a142f;
#   color: #f1f1f1;
# }
# #T_d9632_row15_col2 {
#   background-color: #0e050f;
#   color: #f1f1f1;
# }
# #T_d9632_row15_col4 {
#   background-color: #154b4e;
#   color: #f1f1f1;
# }
# #T_d9632_row16_col0 {
#   background-color: #19132d;
#   color: #f1f1f1;
# }
# #T_d9632_row16_col1 {
#   background-color: #191129;
#   color: #f1f1f1;
# }
# #T_d9632_row16_col3 {
#   background-color: #cbe8f0;
#   color: #000000;
# }
# #T_d9632_row17_col1 {
#   background-color: #160d21;
#   color: #f1f1f1;
# }
# #T_d9632_row17_col3 {
#   background-color: #c6e1f1;
#   color: #000000;
# }
# #T_d9632_row18_col0 {
#   background-color: #150b1d;
#   color: #f1f1f1;
# }
# #T_d9632_row18_col1, #T_d9632_row19_col0, #T_d9632_row20_col2 {
#   background-color: #140a1b;
#   color: #f1f1f1;
# }
# #T_d9632_row18_col3 {
#   background-color: #d1edef;
#   color: #000000;
# }
# #T_d9632_row18_col4 {
#   background-color: #1b6145;
#   color: #f1f1f1;
# }
# #T_d9632_row19_col1, #T_d9632_row19_col2 {
#   background-color: #130919;
#   color: #f1f1f1;
# }
# #T_d9632_row19_col4 {
#   background-color: #cf7e8f;
#   color: #f1f1f1;
# }
# #T_d9632_row20_col0 {
#   background-color: #120817;
#   color: #f1f1f1;
# }
# #T_d9632_row20_col1, #T_d9632_row21_col0 {
#   background-color: #100713;
#   color: #f1f1f1;
# }
# #T_d9632_row20_col3 {
#   background-color: #c5b8ef;
#   color: #000000;
# }
# #T_d9632_row20_col4 {
#   background-color: #cca6e4;
#   color: #000000;
# }
# #T_d9632_row21_col1, #T_d9632_row21_col2 {
#   background-color: #0f0611;
#   color: #f1f1f1;
# }
# #T_d9632_row21_col3 {
#   background-color: #c2d4f3;
#   color: #000000;
# }
# #T_d9632_row21_col4 {
#   background-color: #bc7967;
#   color: #f1f1f1;
# }
# #T_d9632_row22_col1, #T_d9632_row23_col0, #T_d9632_row23_col2 {
#   background-color: #0a030a;
#   color: #f1f1f1;
# }
# #T_d9632_row22_col3 {
#   background-color: #c1d1f3;
#   color: #000000;
# }
# #T_d9632_row22_col4 {
#   background-color: #d2809c;
#   color: #f1f1f1;
# }
# #T_d9632_row23_col1 {
#   background-color: #080308;
#   color: #f1f1f1;
# }
# #T_d9632_row23_col3 {
#   background-color: #c6e0f1;
#   color: #000000;
# }
# #T_d9632_row23_col4 {
#   background-color: #d48dc1;
#   color: #f1f1f1;
# }
# #T_d9632_row24_col0, #T_d9632_row33_col4 {
#   background-color: #070206;
#   color: #f1f1f1;
# }
# #T_d9632_row24_col1, #T_d9632_row24_col2 {
#   background-color: #050205;
#   color: #f1f1f1;
# }
# #T_d9632_row24_col3 {
#   background-color: #c2d6f3;
#   color: #000000;
# }
# #T_d9632_row24_col4, #T_d9632_row36_col4 {
#   background-color: #c87b7c;
#   color: #f1f1f1;
# }
# #T_d9632_row25_col0, #T_d9632_row25_col1, #T_d9632_row26_col0 {
#   background-color: #030103;
#   color: #f1f1f1;
# }
# #T_d9632_row25_col2, #T_d9632_row26_col1, #T_d9632_row26_col2, #T_d9632_row27_col0, #T_d9632_row27_col1, #T_d9632_row27_col2, #T_d9632_row28_col0, #T_d9632_row28_col2, #T_d9632_row29_col0, #T_d9632_row29_col1 {
#   background-color: #020102;
#   color: #f1f1f1;
# }
# #T_d9632_row25_col3 {
#   background-color: #d6f0ef;
#   color: #000000;
# }
# #T_d9632_row25_col4 {
#   background-color: #8d7a3d;
#   color: #f1f1f1;
# }
# #T_d9632_row26_col4 {
#   background-color: #6f7b31;
#   color: #f1f1f1;
# }
# #T_d9632_row27_col3 {
#   background-color: #c8e4f0;
#   color: #000000;
# }
# #T_d9632_row27_col4 {
#   background-color: #d383a6;
#   color: #f1f1f1;
# }
# #T_d9632_row28_col1, #T_d9632_row29_col2, #T_d9632_row30_col0,

# %%
#top 10 active cases states

# %%
Top_Active=covid_df.groupby(by= "State/UnionTerritory").max()[['Active_Cases','Date']].sort_values(by = ["Active_Cases"],ascending=False).reset_index()

# %%
Top_Active
# Out:
#                         State/UnionTerritory  Active_Cases       Date
# 0                                Maharashtra      701614.0 2021-05-19
# 1                                  Karnataka      605515.0 2021-05-19
# 2                                     Kerala      445692.0 2021-05-19
# 3                              Uttar Pradesh      310783.0 2021-05-19
# 4                                 Tamil Nadu      242929.0 2021-05-19
# 5                                  Rajasthan      212753.0 2021-05-19
# 6                             Andhra Pradesh      211554.0 2021-05-19
# 7                                    Gujarat      148297.0 2021-05-19
# 8                                West Bengal      131948.0 2021-05-19
# 9                               Chhattisgarh      131245.0 2021-05-19
# 10                                   Haryana      116867.0 2021-05-19
# 11                                     Bihar      115152.0 2021-05-19
# 12                            Madhya Pradesh      111366.0 2021-05-19
# 13                                     Delhi      103424.0 2021-05-19
# 14                                    Odisha       95743.0 2021-05-19
# 15                                 Telangana       80695.0 2021-05-19
# 16                               Uttarakhand       80000.0 2021-05-19
# 17                                    Punjab       79963.0 2021-05-19
# 18                                 Telengana       78888.0 2021-05-01
# 19                                 Jharkhand       61195.0 2021-05-19
# 20                         Jammu and Kashmir       52848.0 2021-05-19
# 21                                     Assam       47740.0 2021-05-19
# 22                          Himachal Pradesh       40008.0 2021-05-19
# 23                                       Goa       32953.0 2021-05-19
# 24                                Puducherry       17666.0 2021-05-19
# 25          Cases being reassigned to states        9265.0 2020-07-18
# 26                                Chandigarh        8653.0 2021-05-19
# 27                                   Tripura        7584.0 2021-05-19
# 28                                   Manipur        6605.0 2021-05-19
# 29                                 Meghalaya        5332.0 2021-05-19
# 30                                  Nagaland        4407.0 2021-05-19
# 31                                    Sikkim        3096.0 2021-05-19
# 32                         Arunachal Pradesh        3068.0 2021-05-19
# 33                                   Mizoram        2158.0 2021-05-19
# 34  Dadra and Nagar Haveli and Daman and Diu        2081.0 2021-05-19
# 35                                    Ladakh        2041.0 2021-05-19
# 36                               Lakshadweep        1438.0 2021-05-19
# 37               Andaman and Nicobar Islands        1154.0 2021-05-19
# 38                                Unassigned          77.0 2020-04-03
# 39                               Daman & Diu           2.0 2020-06-11

# %%
fig=plt.figure(figsize=(16,9))

# %%
plt.title("Top 10 States with most active cases in india",size=25)
# Out:
# Text(0.5, 1.0, 'Top 10 States with most active cases in india')

# %%
ax=sns.barplot(data=Top_Active.iloc[:10],y="Active_Cases",x="State/UnionTerritory",linewidth=2,edgecolor="white")

# %%
fig=plt.figure(figsize=(16,9))
plt.title("Top 10 States with most active cases in india",size=25)

ax=sns.barplot(data=Top_Active.iloc[:10],
               y="Active_Cases",
               x="State/UnionTerritory",
               linewidth=2,
               edgecolor="white")
plt.xlabel("States")
plt.ylabel("Active cases")
plt.show()

# %%
top10deaths=covid_df.groupby(by = "State/UnionTerritory").max()[["Deaths","Date"]].sort_values(by =["Deaths"],ascending=False)

# %%
#top states with highest deaths

# %%
fig=plt.figure(figsize=(18,5))
plt.title("Top 10 states with most deaths",size=25)
ax=sns.barplot(data=top10deaths.iloc[:12],
               y="Deaths",
               x="State/UnionTerritory",
               linewidth=2,
               edgecolor="White")
plt.xlabel("States")
plt.ylabel("Total Death Cases")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 3
#       1 fig=plt.figure(figsize=(18,5))
#       2 plt.title("Top 10 states with most deaths",size=25)
# ----> 3 ax=sns.barplot(data=top10deaths.iloc[:12],
#       4                y="Deaths",
#       5                x="State/UnionTerritory",
#       6                linewidth=2,
#       7                edgecolor="White")
#       8 plt.xlabel("States")
#       9 plt.ylabel("Total Death Cases")
#
# File ~\anaconda3\lib\site-packages\seaborn\categorical.py:2755, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2752 if estimator is len:
#    2753     estimator = "size"
# -> 2755 plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    2756                       estimator, errorbar, n_boot, units, seed,
#    2757                       orient, color, palette, saturation,
#    2758                       width, errcolor, errwidth, capsize, dodge)
#    2760 if ax is None:
#    2761     ax = plt.gca()
#
# File ~\anaconda3\lib\site-packages\seaborn\categorical.py:1530, in _BarPlotter.__init__(self, x, y, hue, data, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge)
#    1525 def __init__(self, x, y, hue, data, order, hue_order,
#    1526              estimator, errorbar, n_boot, units, seed,
#    1527              orient, color, palette, saturation, width,
#    1528              errcolor, errwidth, capsize, dodge):
#    1529     """Initialize the plotter."""
# -> 1530     self.establish_variables(x, y, hue, data, orient,
#    1531                              order, hue_order, units)
#    1532     self.establish_colors(color, palette, saturation)
#    1533     self.estimate_statistic(estimator, errorbar, n_boot, seed)
#
# File ~\anaconda3\lib\site-packages\seaborn\categorical.py:541, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     539     if isinstance(var, str):
#     540         err = f"Could not interpret input '{var}'"
# --> 541         raise ValueError(err)
#     543 # Figure out the plotting orientation
#     544 orient = infer_orient(
#     545     x, y, orient, require_numeric=self.require_numeric
#     546 )
#
# ValueError: Could not interpret input 'State/UnionTerritory'

# %%
# Check the column names and data types
print(top10deaths.dtypes)

# Plot the bar chart
fig = plt.figure(figsize=(18, 5))
plt.title("Top 10 states with most deaths", size=25)
ax = sns.barplot(x=top10deaths.index[:12],  # Using the index as x values
                 y=top10deaths["Deaths"].iloc[:12],
                 linewidth=2,
                 edgecolor="white")
plt.xlabel("States")
plt.ylabel("Total Death Cases")
plt.show()
# Out:
# Deaths           float64
# Date      datetime64[ns]
# dtype: object
